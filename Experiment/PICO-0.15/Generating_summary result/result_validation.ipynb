# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to find the epoch with the best score
def find_best_epoch(data):
    best_epoch = np.argmax(data) + 1  # Adding 1 because epochs start from 1
    best_score = np.max(data)
    return best_epoch, best_score

# Load the data from .npy files

# bertscore_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\BERTscore.npy')
# rouge1_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\rouge1.npy')
# rouge2_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\rouge2.npy')
# rougeL_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\rougeL.npy')

# Create subplots

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 12))

# Function to plot data
def plot_data(ax, data, title):
    epochs = range(1, len(data) + 1)
    ax.plot(epochs, data)  # Epochs start from 1
    best_epoch, best_score = find_best_epoch(data)
    ax.scatter(best_epoch, best_score, color='red')
    ax.text(best_epoch, best_score, f'Best: {best_score:.2f} at epoch {best_epoch}')
    ax.set_title(title)
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Score')
    ax.set_xticks(epochs)  # Explicitly set x-ticks
    ax.set_xticklabels(epochs)  # Explicitly set x-tick labels


# metrics = ['rouge1', 'rouge2', 'rougeL','BERTscore']
# score_dict = {}
# for metric in metrics:
#     filename = rf'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-10\{metric}.npy'
#     score_dict[metric] = np.load(filename)
# print(score_dict)


#plot_data(axs[0, 0], bartscore_data, 'BERTscore')
# Plot BERTscore
plot_data(axs[0, 0], bertscore_data, 'BERTscore')

# Plot ROUGE-1
plot_data(axs[0, 1], rouge1_data, 'ROUGE-1')

# Plot ROUGE-2
plot_data(axs[1, 0], rouge2_data, 'ROUGE-2')

# Plot ROUGE-L
plot_data(axs[1, 1], rougeL_data, 'ROUGE-L')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# {'rouge1': array([0.25425183, 0.24636672, 0.24442372]), 'rouge2': array([0.05109925, 0.05079719, 0.04807815]), 'rougeL': array([0.16598252, 0.1620849 , 0.1612506 ]), 'BERTscore': array([0.85614067, 0.85262197, 0.853872  ])}

# %%
metrics = ['rouge1', 'rouge2', 'rougeL','BERTscore']
score_dict = {}
for metric in metrics:
    filename = rf'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\{metric}.npy'
    score_dict[metric] = np.load(filename)
print(score_dict)
# Out:
# {'rouge1': array([0.24843208, 0.25455131, 0.25690508]), 'rouge2': array([0.04911348, 0.05038674, 0.05407169]), 'rougeL': array([0.16223186, 0.1646181 , 0.17048465]), 'BERTscore': array([0.85419554, 0.85577393, 0.85652179])}

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Function to find the epoch with the best score
# def find_best_epoch(data):
#     best_epoch = np.argmax(data) + 1  # Adding 1 because epochs start from 1
#     best_score = np.max(data)
#     return best_epoch, best_score

# # Function to plot data
# def plot_data(ax, data, title):
#     epochs = range(1, len(data) + 1)
#     ax.plot(epochs, data)  # Epochs start from 1
#     best_epoch, best_score = find_best_epoch(data)
#     ax.scatter(best_epoch, best_score, color='red')
#     ax.text(best_epoch, best_score, f'Best: {best_score:.2f} at epoch {best_epoch}')
#     ax.set_title(title)
#     ax.set_xlabel('Epochs')
#     ax.set_ylabel('Score')
#     ax.set_xticks(epochs)  # Explicitly set x-ticks
#     ax.set_xticklabels(epochs)  # Explicitly set x-tick labels

# # Load the data from .npy files
# bartscore_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\BARTscore.npy')

# # Create a single plot
# fig, ax = plt.subplots(figsize=(12, 12))

# # Plot BARTscore
# plot_data(ax, bartscore_data, 'BARTscore')

# # Show the plots
# plt.tight_layout()
# plt.show()

# %%
metrics = ['rouge1', 'rouge2', 'rougeL','BERTscore']
score_dict = {}
for metric in metrics:
    filename = rf'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\{metric}.npy'
    score_dict[metric] = np.load(filename)
print(score_dict)
# Out:
# {'rouge1': array([0.24843208, 0.25455131, 0.25690508]), 'rouge2': array([0.04911348, 0.05038674, 0.05407169]), 'rougeL': array([0.16223186, 0.1646181 , 0.17048465]), 'BERTscore': array([0.85419554, 0.85577393, 0.85652179])}

# %%
metrics = ['rouge1', 'rouge2', 'rougeL','BERTscore']
score_dict = {}
for metric in metrics:
    filename = rf'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.45\Top-20-cnn\{metric}.npy'
    score_dict[metric] = np.load(filename)
print(score_dict)
# Out:
# {'rouge1': array([0.24780751]), 'rouge2': array([0.05317412]), 'rougeL': array([0.16953002]), 'BERTscore': array([0.85814995])}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to find the epoch with the best score
def find_best_epoch(data):
    best_epoch = np.argmax(data) + 1  # Adding 1 because epochs start from 1
    best_score = np.max(data)
    return best_epoch, best_score

# Load the data from .npy files

bertscore_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\BERTscore.npy')
rouge1_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\rouge1.npy')
rouge2_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\rouge2.npy')
rougeL_data = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\rougeL.npy')

# Create subplots

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 12))

# Function to plot data
def plot_data(ax, data, title):
    epochs = range(1, len(data) + 1)
    ax.plot(epochs, data)  # Epochs start from 1
    best_epoch, best_score = find_best_epoch(data)
    ax.scatter(best_epoch, best_score, color='red')
    ax.text(best_epoch, best_score, f'Best: {best_score:.2f} at epoch {best_epoch}')
    ax.set_title(title)
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Score')
    ax.set_xticks(epochs)  # Explicitly set x-ticks
    ax.set_xticklabels(epochs)  # Explicitly set x-tick labels


#plot_data(axs[0, 0], bartscore_data, 'BERTscore')
# Plot BERTscore
plot_data(axs[0, 0], bertscore_data, 'BERTscore')

plot_data(axs[0, 1], rouge1_data, 'ROUGE-1')
plot_data(axs[1, 0], rouge2_data, 'ROUGE-2')
plot_data(axs[1, 1], rougeL_data, 'ROUGE-L')


plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

train_losses = np.load(r'C:\Users\ayush\OneDrive\Documents\GitHub\Multi-document-summarization-for-medical-literature\Experiment\PICO-0.15\Generating_summary result\Top-20\train_losses.npy')


step_per_ep = train_losses.shape[-1]


flattened_train_losses = train_losses.ravel()


smoothed_losses = np.convolve(flattened_train_losses, np.ones(10) / 10, mode='same')

plt.figure(figsize=(10, 6))
plt.plot(range(step_per_ep * train_losses.shape[0]), smoothed_losses, label='Training loss')

for i in range(1, train_losses.shape[0]):
    plt.axvline(i * step_per_ep, linestyle='--', color='gray')


plt.xlabel('Training steps')
plt.ylabel('Loss (log scale)')
plt.title('Training losses')
plt.legend()

plt.yscale('log')


plt.show()
